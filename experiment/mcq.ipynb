# %%
import os
import json
import pandas as pd
import traceback
from dotenv import load_dotenv

# %%
# !pip install python-dotenv

# %%
from langchain.chat_models import ChatOpenAI
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from langchain.chat_models import ChatOpenAI
#
# File ~/mcqgen/env/lib/python3.8/site-packages/langchain/chat_models/__init__.py:28, in __getattr__(name)
#      27 def __getattr__(name: str) -> None:
# ---> 28     from langchain_community import chat_models
#      30     # If not in interactive env, raise warning.
#      31     if not is_interactive_env():
#
# ModuleNotFoundError: No module named 'langchain_community'

# %%
# !pip install langchain
# Out:
# ...
#   Using cached langchain-0.2.3-py3-none-any.whl.metadata (6.9 kB)
# ...
#   Using cached PyYAML-6.0.1-cp38-cp38-macosx_10_9_x86_64.whl.metadata (2.1 kB)
# ...
#   Using cached SQLAlchemy-2.0.30-cp38-cp38-macosx_10_9_x86_64.whl.metadata (9.6 kB)
# ...
#   Using cached aiohttp-3.9.5-cp38-cp38-macosx_10_9_x86_64.whl.metadata (7.5 kB)
# ...
#   Using cached async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# ...
#   Using cached langchain_core-0.2.5-py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached langchain_text_splitters-0.2.1-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached langsmith-0.1.76-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached pydantic-2.7.3-py3-none-any.whl.metadata (108 kB)
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached tenacity-8.3.0-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# ...
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# ...

# %%
# !pip install --upgrade pip

# %%
# !pip install --user langchain
# Out:
# ...
#   Using cached langchain-0.2.3-py3-none-any.whl.metadata (6.9 kB)
# ...
#   Using cached PyYAML-6.0.1-cp38-cp38-macosx_10_9_x86_64.whl.metadata (2.1 kB)
# ...
#   Using cached SQLAlchemy-2.0.30-cp38-cp38-macosx_10_9_x86_64.whl.metadata (9.6 kB)
# ...
#   Using cached aiohttp-3.9.5-cp38-cp38-macosx_10_9_x86_64.whl.metadata (7.5 kB)
# ...
#   Using cached async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# ...
#   Using cached langchain_core-0.2.5-py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached langchain_text_splitters-0.2.1-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached langsmith-0.1.76-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached pydantic-2.7.3-py3-none-any.whl.metadata (108 kB)
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached tenacity-8.3.0-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# ...
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# ...

# %%
# !pip install langchain --no-cache-dir
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.0/109.0 kB 1.8 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.0/182.0 kB 4.0 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.0/974.0 kB 13.1 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 402.6/402.6 kB 78.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.7/314.7 kB 69.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.9/124.9 kB 128.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.6/409.6 kB 91.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 33.8 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# !pip install langchain_community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 6.6 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 831.2 kB/s eta 0:00:00a 0:00:01
# ...

# %%
# Step 1: Upgrade pip, setuptools, and wheel to ensure compatibility
# !pip install --upgrade pip setuptools wheel

# Step 2: Install langchain_community manually
# !pip install langchain_community

# Step 3: Reinstall langchain to ensure all dependencies are met
# !pip install --upgrade langchain

# Step 4: Verify the installation by importing ChatOpenAI
from langchain.chat_models import ChatOpenAI
print("langchain installed successfully")
# Out:
# ...
#   Using cached setuptools-70.0.0-py3-none-any.whl.metadata (5.9 kB)
# ...
# Using cached setuptools-70.0.0-py3-none-any.whl (863 kB)
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 69.5.1
#     Uninstalling setuptools-69.5.1:
#       Successfully uninstalled setuptools-69.5.1
# ...
# langchain installed successfully

# %%
from langchain.chat_models import ChatOpenAI

# %%
KEY=os.getenv("OPENAI_API_KEY")
print(KEY)
# Out:
# None

# %%
llm=ChatOpenAI(openai_api_key=KEY,model_name='gpt-3.5-turbo', temperature=0.5)

# %%
import os
import pandas as pd
import traceback
from dotenv import load_dotenv

# Load environment variables from a .env file
load_dotenv()

# Retrieve the API key from the environment variable
KEY = os.getenv("OPENAI_API_KEY")

# Check if the API key was retrieved successfully
if KEY:
    print("API key retrieved successfully3.")
else:
    print("API key not found. Please set the OPENAI_API_KEY environment variable.")
# Out:
# API key retrieved successfully.
